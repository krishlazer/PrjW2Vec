# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
#from sklearn.feature_extraction.text import CountVectorizer
import re
import nltk

# %%
dfamzrev = pd.read_csv('E:/KrishM/PythonPrjs/PyDatasets/Reviews/amazonlabelled.txt', delimiter='\t', header=None)

# %%
dfzmzcols = ['Review_Text', 'Review_Class']

# %%
dfimdrev = pd.read_csv('E:/KrishM/PythonPrjs/PyDatasets/Reviews/imdblabelled.txt', delimiter='\t', header=None)

# %%
dfimdcols = ['Review_Text', 'Review_Class']

# %%
dfyelrev = pd.read_csv('E:/KrishM/PythonPrjs/PyDatasets/Reviews/yelplabelled.txt', delimiter='\t', header=None)

# %%
dfyelcols = ['Review_Text', 'Review_Class']

# %%
dfreview = pd.concat([dfamzrev, dfimdrev, dfyelrev], ignore_index=True)

# %%
dfreview.columns = dfimdcols

# %%
dfreview
# Out:
#                                             Review_Text  Review_Class
# 0     So there is no way for me to plug it in here i...             0
# 1                           Good case, Excellent value.             1
# 2                                Great for the jawbone.             1
# 3     Tied to charger for conversations lasting more...             0
# 4                                     The mic is great.             1
# ...                                                 ...           ...
# 2743  I think food should have flavor and texture an...             0
# 2744                           Appetite instantly gone.             0
# 2745  Overall I was not impressed and would not go b...             0
# 2746  The whole experience was underwhelming, and I ...             0
# 2747  Then, as if I hadn't wasted enough of my life ...             0
#
# [2748 rows x 2 columns]

# %%
for n in range(len(lstreview)):
    lstreview[n] = [w for w in lstreview[n] if w.isalpha()]

# %%
for m in range(len(lstreview)):
    lstreview[m] = [wrd.lower() for wrd in lstreview[m] if wrd not in sw]

# %%
lstreview[0]
# Out:
# ['so', 'way', 'plug', 'us', 'unless', 'i', 'go']

# %%
lstreview
# Out:
# [['so', 'way', 'plug', 'us', 'unless', 'i', 'go'],
#  ['good', 'excellent'],
#  ['great'],
#  ['tied', 'charger', 'conversations', 'lasting'],
#  ['the', 'mic'],
#  ['i', 'jiggle', 'plug', 'get', 'line', 'right', 'get', 'decent'],
#  ['if',
#   'several',
#   'dozen',
#   'several',
#   'hundred',
#   'imagine',
#   'fun',
#   'sending',
#   'one'],
#  ['if', 'razr', 'must'],
#  ['needless', 'i', 'wasted'],
#  ['what', 'waste', 'money'],
#  ['and', 'sound', 'quality'],
#  ['he', 'impressed', 'going', 'original', 'battery', 'extended'],
#  ['if',
#   'two',
#   'seperated',
#   'mere',
#   'ft',
#   'i',
#   'started',
#   'notice',
#   'excessive',
#   'static',
#   'garbled',
#   'sound'],
#  ['very', 'good', 'quality', 'though'],
#  ['the', 'design', 'ear', 'not', 'comfortable'],
#  ['highly', 'recommend', 'one', 'blue', 'tooth'],
#  ['i', 'advise', 'everyone', 'do', 'not', 'be'],
#  ['so', 'far', 'so'],
#  ['works'],
#  ['it',
#   'clicks',
#   'place',
#   'way',
#   'makes',
#   'wonder',
#   'long',
#   'mechanism',
#   'would'],
#  ['i', 'went', 'website', 'followed', 'could', 'not', 'get', 'pair'],
#  ['i', 'bought', 'use', 'kindle', 'fire', 'absolutely', 'loved'],
#  ['the', 'commercials'],
#  ['i',
#   'yet',
#   'run',
#   'new',
#   'battery',
#   'two',
#   'bars',
#   'three',
#   'days',
#   'without'],
#  ['i', 'bought', 'mother', 'problem'],
#  ['great', 'pocket', 'pc', 'phone'],
#  ['owned', 'phone', 'months', 'say', 'best', 'mobile', 'phone'],
#  ['i', 'think', 'instructions', 'provided', 'helpful'],
#  ['people', 'couldnt', 'hear', 'talk', 'i', 'pull', 'earphone', 'talk'],
#  ['hold'],
#  ['this', 'simple', 'little', 'phone', 'breakage'],
#  ['this', 'product', 'ideal', 'people', 'like', 'whose', 'ears'],
#  ['it', 'unusable', 'moving', 'car', 'freeway'],
#  ['i', 'two', 'years', 'left', 'contract', 'i', 'hate'],
#  ['car',
#   'charger',
#   'well',
#   'ac',
#   'charger',
#   'included',
#   'make',
#   'sure',
#   'never',
#   'run',
#   'recommended'],
#  ['you',
#   'need',
#   'least',
#   'mins',
#   'get',
#   'phone',
#   'book',
#   'time',
#   'first',
#   'turn',
#   'life'],
#  ['it', 'kept'],
#  ['poor', 'talk', 'time'],
#  ['the', 'case', 'great', 'works', 'fine'],
#  ['worthless'],
#  ['it',
#   'great',
#   'camera',
#   'thats',
#   'pics',
#   'nice',
#   'clear',
#   'great',
#   'picture'],
#  ['i', 'not', 'impressed'],
#  ['nice', 'headset', 'priced'],
#  ['i', 'hear', 'garbage'],
#  ['excellent', 'bluetooth'],
#  ['it', 'features', 'i', 'want'],
#  ['who', 'right', 'mind', 'gonna', 'buy'],
#  ['after',
#   'arguing',
#   'with',
#   'verizon',
#   'regarding',
#   'the',
#   'dropped',
#   'calls',
#   'we',
#   'returned',
#   'the',
#   'phones',
#   'after',
#   'two'],
#  ['this', 'case', 'seems', 'well'],
#  ['disappointed'],
#  ['not', 'loud', 'enough', 'turn', 'like'],
#  ['good', 'protection', 'not', 'make', 'phone'],
#  ['a',
#   'usable',
#   'keyboard',
#   'actually',
#   'turns',
#   'pda',
#   'useful',
#   'machine',
#   'instead',
#   'neat'],
#  ['this', 'phone', 'pretty', 'sturdy', 'never', 'large', 'problems'],
#  ['i', 'love'],
#  ['everything', 'fine', 'reasonable', 'price'],
#  ['very'],
#  ['i',
#   'even',
#   'dropped',
#   'phone',
#   'stream',
#   'submerged',
#   'seconds',
#   'still',
#   'works'],
#  ['i', 'happy', 'no', 'complaints', 'one', 'regarding', 'sound', 'quality'],
#  ['the', 'buttons'],
#  ['essentially', 'forget', 'tech'],
#  ['i', 'really', 'recommend', 'faceplates', 'since', 'looks', 'elegant'],
#  ['these',
#   'headphones',
#   'great',
#   'find',
#   'i',
#   'think',
#   'perhaps',
#   'best',
#   'purchase',
#   'made',
#   'last',
#   'several',
#   'years'],
#  ['buy', 'different', 'phone', 'not'],
#  ['you', 'hold', 'phone', 'particular', 'angle', 'party', 'hear'],
#  ['the',
#   'one',
#   'big',
#   'drawback',
#   'player',
#   'buttons',
#   'front',
#   'cover',
#   'let',
#   'pause',
#   'skip',
#   'songs',
#   'lock'],
#  ['a', 'week', 'later', 'i', 'activated', 'suddenly'],
#  ['it',
#   'feels',
#   'comfortable',
#   'headsets',
#   'i',
#   'wear',
#   'glasses',
#   'gets',
#   'way'],
#  ['great', 'ipods'],
#  ['this', 'device', 'great', 'several'],
#  ['mic'],
#  ['even', 'bmw', 'series', 'fairly', 'i', 'trouble', 'hearing', 'person'],
#  ['great'],
#  ['nice', 'docking', 'station', 'home'],
#  ['this', 'beautiful'],
#  ['love'],
#  ['do', 'not', 'buy', 'advertised'],
#  ['this', 'great', 'little'],
#  ['i', 'love', 'phone', 'it', 'handy', 'lot', 'features'],
#  ['i', 'purchased', 'within', 'days', 'longer'],
#  ['i', 'wear', 'everyday', 'holds'],
#  ['not', 'good'],
#  ['well', 'arrived', 'works'],
#  ['the', 'battery', 'runs'],
#  ['this', 'item', 'worked', 'broke', 'months'],
#  ['the', 'headsets', 'easy', 'use', 'everyone', 'loves'],
#  ['this', 'phone', 'works'],
#  ['the', 'construction', 'headsets'],
#  ['product', 'excellent', 'works', 'better', 'verizon', 'one', 'boy'],
#  ['the', 'phone', 'loads'],
#  ['for',
#   'product',
#   'costs',
#   'much',
#   'one',
#   'i',
#   'expect',
#   'work',
#   'far',
#   'better',
#   'greater',
#   'ease',
#   'thing'],
#  ['made'],
#  ['worked'],
#  ['the', 'ear', 'buds', 'play', 'music', 'one'],
#  ['dont', 'waste'],
#  ['will', 'order'],
#  ['if', 'plan', 'use', 'car', 'forget'],
#  ['i', 'found', 'product', 'waaay'],
#  ['best',
#   'found',
#   'far',
#   'tried',
#   'bluetooths',
#   'one',
#   'best',
#   'quality',
#   'well',
#   'ease'],
#  ['disappointed'],
#  ['integrated', 'seamlessly', 'motorola', 'razr'],
#  ['buyer', 'could', 'flush', 'money', 'right'],
#  ['definitely'],
#  ['the', 'price', 'good', 'free', 'shipping', 'good'],
#  ['i',
#   'received',
#   'supposedly',
#   'new',
#   'motorola',
#   'apparently',
#   'not',
#   'match',
#   'phone'],
#  ['camera', 'nice', 'pictures', 'also', 'cool', 'styles', 'like', 'black'],
#  ['huge', 'design', 'flaw', 'not', 'using', 'i', 'think'],
#  ['i',
#   'love',
#   'my',
#   'bluetooth',
#   'headset',
#   'reception',
#   'good',
#   'ear',
#   'piece',
#   'comfortable'],
#  ['the',
#   'although',
#   'rated',
#   'impressive',
#   'renders',
#   'images',
#   'fall',
#   'well',
#   'expectations',
#   'relatively',
#   'high'],
#  ['i', 'purcashed', 'car', 'charger', 'not'],
#  ['sound',
#   'quality',
#   'end',
#   'i',
#   'use',
#   'headset',
#   'call',
#   'wife',
#   'ask',
#   'wife',
#   'use',
#   'headset',
#   'call'],
#  ['this', 'phone', 'slim', 'light', 'display'],
#  ['little',
#   'geeky',
#   'think',
#   'thats',
#   'sex',
#   'toast',
#   'rocks',
#   'oozes',
#   'sex',
#   'right',
#   'battery',
#   'embedded',
#   'sleek',
#   'stylish',
#   'leather'],
#  ['great', 'fast'],
#  ['absolutely'],
#  ['the',
#   'keyboard',
#   'nice',
#   'compromise',
#   'full',
#   'qwerty',
#   'basic',
#   'cell',
#   'phone',
#   'number'],
#  ['got', 'phone', 'around', 'end', 'may', 'completely', 'unhappy'],
#  ['it', 'comfortable'],
#  ['it', 'winner'],
#  [],
#  ['tried',
#   'several',
#   'different',
#   'earpieces',
#   'cell',
#   'phone',
#   'jabra',
#   'one',
#   'first',
#   'one',
#   'found',
#   'fits',
#   'ear'],
#  ['could', 'not', 'get', 'strong', 'enough'],
#  ['iam', 'pleased'],
#  ['bad'],
#  ['gets', 'job'],
#  ['great'],
#  ['basically', 'service'],
#  ['not', 'work', 'cell', 'phone', 'plug', 'set'],
#  ['bluetooth', 'i', 'really', 'like'],
#  ['the', 'bt', 'headset'],
#  ['it', 'small', 'even', 'realize', 'getting', 'used'],
#  ['the', 'accompanied', 'software', 'almost'],
#  ['headset', 'works', 'great', 'packaged', 'nicely', 'avoid'],
#  ['definitly'],
#  ['very'],
#  ['the', 'majority', 'logitech', 'earbud', 'headsets'],
#  ['very', 'good', 'stuff'],
#  ['my', 'headset', 'works'],
#  ['in',
#   'house',
#   'i',
#   'getting',
#   'dropped',
#   'coverage',
#   'upstairs',
#   'coverage'],
#  ['voice', 'recognition'],
#  ['what'],
#  ['during',
#   'several',
#   'different',
#   'minute',
#   'i',
#   'experienced',
#   'drops',
#   'area'],
#  ['i', 'not', 'happy'],
#  [],
#  ['the', 'phone', 'takes', 'forever', 'charge', 'like', 'hours'],
#  ['i', 'got', 'phone', 'reccomendation', 'relative', 'glad', 'i'],
#  ['what', 'waste'],
#  ['its', 'reception'],
#  ['items', 'stated', 'included', 'description', 'are', 'not'],
#  ['after', 'screen', 'went', 'black'],
#  ['i', 'was', 'hoping'],
#  ['audio', 'quality'],
#  ['i', 'absolutely', 'problem', 'headset', 'linking', 'blackberry'],
#  ['i',
#   'know',
#   'sounds',
#   'seemed',
#   'like',
#   'sketchy',
#   'technology',
#   'work',
#   'one',
#   'works'],
#  ['bought', 'wired', 'headphones', 'sound', 'better'],
#  ['this',
#   'phone',
#   'fast',
#   'sending',
#   'kind',
#   'messages',
#   'web',
#   'browsing',
#   'significantly',
#   'faster',
#   'previous',
#   'phones'],
#  ['nice', 'quality', 'unlike', 'cheap'],
#  ['this', 'item', 'fantastic', 'works'],
#  ['and', 'i', 'love'],
#  [],
#  ['all', 'i', 'whine', 'i', 'use', 'thing', 'less', 'i', 'like'],
#  ['great'],
#  ['this', 'essentially', 'communications', 'tool', 'not'],
#  ['works', 'like', 'work', 'one', 'i', 'got'],
#  ['i',
#   'still',
#   'maintain',
#   'monkeys',
#   'make',
#   'obviously',
#   'share',
#   'enough',
#   'dna',
#   'copy',
#   'design'],
#  ['great'],
#  ['work', 'i', 'bougth', 'not'],
#  ['the', 'look', 'sharp', 'screen', 'nice', 'great'],
#  ['last'],
#  ['one', 'thing', 'i', 'hate', 'mode', 'set', 'button'],
#  ['excellent'],
#  ['thank', 'wasting'],
#  ['how', 'audio', 'quality'],
#  ['the', 'igo', 'chargers', 'tips', 'really'],
#  ['the', 'file', 'browser', 'offers', 'options', 'one'],
#  ['superb', 'phone', 'great'],
#  ['i',
#   'connected',
#   'phone',
#   'worked',
#   'like',
#   'charm',
#   'whether',
#   'phone',
#   'pocket'],
#  ['i', 'put', 'latest', 'os', 'likes', 'slow', 'crawl', 'lock', 'every'],
#  ['it', 'recognizes', 'phone', 'storage'],
#  ['if', 'like', 'loud', 'buzzing', 'override', 'phone'],
#  ['buy'],
#  ['bluetoooth',
#   'headset',
#   'time',
#   'still',
#   'not',
#   'comfortable',
#   'way',
#   'fits'],
#  ['the', 'sound', 'quality', 'good', 'functionality'],
#  ['i', 'phone', 'thorn', 'i', 'really', 'abhor'],
#  ['i',
#   'recently',
#   'problems',
#   'i',
#   'could',
#   'not',
#   'stay',
#   'connected',
#   'minutes'],
#  [],
#  ['design'],
#  ['great'],
#  ['waste'],
#  ['but',
#   'i',
#   'check',
#   'voice',
#   'mail',
#   'keypad',
#   'backlight',
#   'turns',
#   'seconds',
#   'first'],
#  ['the', 'replacement', 'died'],
#  ['any', 'ring', 'good', 'phone'],
#  ['lately', 'extremely', 'nice', 'helpful'],
#  ['i', 'problems', 'wit', 'hit', 'dropping', 'signal'],
#  ['not'],
#  ['light', 'i', 'hardly', 'notice'],
#  ['love', 'thin'],
#  ['bad'],
#  ['the', 'pleather', 'case'],
#  ['useless', 'simply'],
#  ['the',
#   'color',
#   'even',
#   'prettier',
#   'i',
#   'thought',
#   'would',
#   'graphics',
#   'incredibly'],
#  ['all', 'i', 'think', 'good'],
#  ['it', 'makes', 'strange', 'ticking', 'noises', 'ends'],
#  ['the', 'best', 'electronics', 'available', 'fm'],
#  ['battery', 'lasts'],
#  ['great', 'impressed'],
#  ['the', 'mega', 'pixel', 'part', 'reasonably'],
#  ['nearly', 'years', 'worked', 'great'],
#  ['good', 'transmit'],
#  ['we', 'sending'],
#  ['i',
#   'not',
#   'bother',
#   'contacting',
#   'company',
#   'dollar',
#   'product',
#   'i',
#   'learned',
#   'lesson',
#   'i',
#   'not',
#   'bought',
#   'form',
#   'online'],
#  ['if', 'hate', 'avoid', 'phone'],
#  ['great', 'price'],
#  ['the',
#   'range',
#   'able',
#   'roam',
#   'around',
#   'house',
#   'phone',
#   'living',
#   'room',
#   'quality'],
#  ['fast'],
#  ['i', 'would', 'highly', 'recommend'],
#  ['i', 'would', 'recommend'],
#  ['i', 'also', 'like', 'felt', 'like', 'would', 'crack'],
#  ['worst', 'phone'],
#  ['still', 'infatuated'],
#  ['freezes'],
#  ['kind', 'embarrassing', 'use', 'looks', 'mostly', 'embarrassing', 'company'],
#  ['lightweight', 'great'],
#  ['all', 'expected', 'better', 'consumer', 'experience'],
#  ['horrible',
#   'tick',
#   'sound',
#   'background',
#   'calls',
#   'i',
#   'never',
#   'experienced'],
#  ['these', 'certainly', 'comfortable', 'functionality'],
#  ['i', 'usually', 'like', 'headbands', 'one', 'lightweight', 'mess'],
#  ['bit'],
#  ['i', 'phone', 'year', 'i', 'tell', 'not'],
#  ['i',
#   'ordered',
#   'sony',
#   'ericsson',
#   'i',
#   'think',
#   'worked',
#   'i',
#   'first',
#   'used'],
#  ['the', 'battery', 'completely', 'useless'],
#  ['what', 'big', 'waste'],
#  ['waste'],
#  ['great', 'sound'],
#  ['really', 'pleased', 'product'],
#  ['one', 'favorite', 'purchases'],
#  ['best', 'bluetooth'],
#  ['authentic', 'leather', 'nice', 'shine', 'comfort', 'recommend', 'case'],
#  ['i', 'excited', 'get', 'headset', 'i', 'thought', 'really'],
#  ['do', 'not', 'make', 'mistake'],
#  ['big', 'disappointment', 'calendar'],
#  ['phone', 'unusable', 'not'],
#  ['worst', 'customer', 'service'],
#  ['no', 'additional', 'ear', 'gels', 'instructions'],
#  ['it', 'defeats', 'purpose', 'bluetooth'],
#  ['worth', 'every'],
#  ['excellent', 'wallet', 'type', 'phone'],
#  ['nice', 'headphones', 'price', 'work'],
#  ['internet', 'excrutiatingly'],
#  ['it', 'comfortable', 'wear', 'probably', 'important', 'aspect', 'using'],
#  ['fits', 'like', 'glove'],
#  ['o', 'gosh', 'best', 'phone', 'i', 'ever'],
#  ['attractive', 'appears', 'good'],
#  ['i', 'love', 'features', 'form'],
#  ['this', 'product', 'strong', 'smell', 'unbearable', 'caused', 'return'],
#  ['poor', 'quality'],
#  ['the', 'cable', 'looks', 'thin'],
#  ['great'],
#  ['excellent', 'hands', 'free'],
#  ['great', 'using', 'home'],
#  ['good', 'product', 'incredible'],
#  ['only', 'month', 'worked', 'flawlessly'],
#  ['works'],
#  ['absolutel'],
#  ['that', 'one', 'work'],
#  ['battery', 'life', 'real'],
#  ['returned', 'hours'],
#  ['great'],
#  ['waste'],
#  ['love'],
#  ['not', 'drain', 'may', 'also', 'potentially', 'fry'],
#  ['worked'],
#  ['unreliable', 'giving'],
#  ['i', 'gave', 'stars', 'sound'],
#  ['avoid', 'one'],
#  ['reversible', 'plug', 'works'],
#  ['i', 'wasted', 'little', 'money'],
#  ['very', 'good'],
#  ['best', 'rotating'],
#  ['comfort', 'whole'],
#  ['good', 'good'],
#  ['i', 'love'],
#  ['first', 'wear'],
#  ['i', 'impressed', 'headset'],
#  ['i', 'got', 'small'],
#  ['great'],
#  ['i', 'recommend', 'buying'],
#  ['piece'],
#  ['poorly', 'contstruct'],
#  ['this',
#   'item',
#   'installed',
#   'let',
#   'charged',
#   'overnite',
#   'working',
#   'good',
#   'every',
#   'since',
#   'problems'],
#  ['great'],
#  ['buy'],
#  ['excellent'],
#  ['do', 'not', 'purchase', 'this'],
#  ['the', 'voice', 'recognition', 'thru', 'handset'],
#  ['this', 'hands', 'best', 'phone', 'ever'],
#  ['works',
#   'cat',
#   'attacked',
#   'phone',
#   'scratched',
#   'protective',
#   'strip',
#   'instead',
#   'destroying'],
#  ['this', 'one', 'works', 'priced'],
#  ['customer', 'service'],
#  ['battery', 'life', 'still', 'not', 'long', 'enough', 'motorola', 'razor'],
#  ['sending'],
#  ['now', 'i', 'know', 'i', 'made', 'wise'],
#  ['someone', 'shouldve', 'invented'],
#  ['good'],
#  ['everything',
#   'worked',
#   'first',
#   'device',
#   'certainly',
#   'engineered',
#   'clever',
#   'way',
#   'construction',
#   'feels'],
#  ['i', 'received', 'quickly', 'works'],
#  ['has', 'working'],
#  ['as', 'many', 'people', 'i', 'found', 'microphone'],
#  ['my', 'old', 'nokia', 'tracfone', 'holds', 'charge', 'lot', 'better'],
#  ['they', 'not', 'care', 'consumer', 'one'],
#  ['this', 'good', 'got', 'really'],
#  ['the', 'instruction', 'manual'],
#  ['also',
#   'slim',
#   'enough',
#   'fit',
#   'alarm',
#   'clock',
#   'docking',
#   'station',
#   'without',
#   'removing'],
#  ['phone', 'holds', 'charge', 'like'],
#  ['the', 'battery', 'unreliable', 'well', 'service', 'use'],
#  ['uncomfortable',
#   'sound',
#   'quality',
#   'quite',
#   'poor',
#   'compared',
#   'phone',
#   'previous',
#   'wired',
#   'headset',
#   'plugged'],
#  ['we', 'gotten', 'lot', 'compliments'],
#  ['this',
#   'definitely',
#   'must',
#   'state',
#   'not',
#   'allow',
#   'cell',
#   'phone',
#   'usage'],
#  ['i', 'want', 'money'],
#  ['i', 'love'],
#  ['i', 'also', 'happy'],
#  ['i', 'ordered', 'product', 'first', 'unhappy'],
#  ['the', 'ngage', 'still', 'lacking'],
#  ['i', 'able', 'voice', 'dialing', 'car'],
#  ['i', 'bars', 'cell', 'phone', 'i', 'cant', 'not', 'hear'],
#  ['good', 'low'],
#  ['riingtones', 'not', 'neither'],
#  ['the', 'plug', 'not', 'work'],
#  ['amazon'],
#  ['rip', 'over', 'charge'],
#  ['very'],
#  ['the',
#   'battery',
#   'working',
#   'well',
#   'replacement',
#   'original',
#   'came',
#   'phone',
#   'years'],
#  ['the', 'reception'],
#  ['it',
#   'fits',
#   'comfortably',
#   'either',
#   'sound',
#   'clear',
#   'charge',
#   'lasts',
#   'couple'],
#  ['quality', 'sound', 'mess', 'sound', 'ipod', 'since', 'sound', 'buttons'],
#  ['long', 'lasting', 'battery', 'recharge', 'frequentyly', 'flip'],
#  ['obviously', 'problem'],
#  ['very'],
#  ['it', 'inexpensive', 'i', 'would', 'still', 'expected', 'better'],
#  ['it',
#   'practically',
#   'useless',
#   'not',
#   'add',
#   'kind',
#   'boost',
#   'reception',
#   'i',
#   'bought'],
#  ['excellent', 'sound'],
#  ['was', 'not'],
#  ['a',
#   'piece',
#   'of',
#   'junk',
#   'that',
#   'broke',
#   'after',
#   'being',
#   'on',
#   'my',
#   'phone',
#   'for'],
#  ['new', 'battery', 'works', 'great'],
#  ['worst', 'customer'],
#  ['dropped',
#   'phone',
#   'times',
#   'i',
#   'even',
#   'concrete',
#   'phone',
#   'still',
#   'great'],
#  ['reception', 'terrible', 'full'],
#  ['good', 'audio'],
#  ['this',
#   'little',
#   'device',
#   'transformed',
#   'organizational',
#   'capability',
#   'made',
#   'life',
#   'whole',
#   'lot'],
#  ['i', 'sitting', 'cradle', 'headset', 'lost'],
#  ['were', 'jerks'],
#  ['works', 'like', 'works'],
#  ['nice', 'good', 'battery'],
#  ['their', 'network', 'coverage', 'los', 'angeles'],
#  ['excellent', 'starter', 'wireless'],
#  ['the', 'loudspeaker', 'option', 'bumpers', 'lights'],
#  ['the', 'thing', 'i', 'think', 'could', 'improve', 'sound', 'leaks'],
#  ['first', 'reception', 'i', 'never'],
#  ['the', 'phone', 'gets', 'extremely'],
#  ['the', 'microphone', 'also', 'works', 'people', 'i', 'applifies'],
#  ['nice', 'design'],
#  ['phone', 'case', 'not', 'going', 'save', 'specially', 'dropped', 'face'],
#  ['it', 'easy', 'clear', 'reception'],
#  ['bad', 'way'],
#  ['it', 'definitely', 'not', 'good'],
#  ['awesome'],
#  ['waste'],
#  ['i', 'ordered', 'motorola', 'data', 'got', 'well', 'finished', 'working'],
#  ['love', 'this'],
#  ['i', 'looking', 'headset', 'long', 'time', 'got', 'i'],
#  ['drivng', 'headset', 'starts', 'ringing'],
#  ['display', 'excellent', 'camera', 'good'],
#  ['battery', 'life', 'also'],
#  ['the', 'worst', 'phone', 'ever', 'only'],
#  ['not',
#   'good',
#   'it',
#   'worked',
#   'started',
#   'problems',
#   'auto',
#   'reverse',
#   'tape'],
#  ['this',
#   'embarassing',
#   'also',
#   'ears',
#   'hurt',
#   'i',
#   'try',
#   'push',
#   'ear',
#   'plug'],
#  ['protects', 'phone'],
#  ['this',
#   'very',
#   'average',
#   'phone',
#   'bad',
#   'battery',
#   'life',
#   'operates',
#   'weak'],
#  ['clear', 'skype', 'long', 'battery', 'long'],
#  ['soyo', 'technology'],
#  ['great', 'hands', 'free'],
#  ['even', 'take', 'self', 'portraits', 'outside'],
#  ['same', 'problem', 'others'],
#  ['after',
#   'trying',
#   'many',
#   'many',
#   'handsfree',
#   'gadgets',
#   'one',
#   'finally',
#   'works'],
#  ['magical'],
#  ['the', 'worst', 'piece', 'crap', 'ever', 'along', 'verizon', 'customer'],
#  ['poor', 'sound'],
#  ['the', 'best', 'phone', 'market'],
#  ['it', 'worked'],
#  ['the', 'company', 'shipped', 'product', 'promptly', 'works'],
#  ['exactly', 'i'],
#  ['the', 'picture', 'resolution', 'far', 'phones', 'offering'],
#  ['this', 'great'],
#  ['excellent', 'i', 'satisfied'],
#  ['i', 'highly', 'recommend', 'encourage', 'people', 'give'],
#  ['better'],
#  ['using', 'left', 'thing', 'not', 'stay'],
#  ['great', 'product'],
#  ['sounds', 'good', 'reasonably', 'priced', 'its', 'simple'],
#  ['still', 'sure', 'item', 'would', 'work', 'i', 'ever', 'recieve'],
#  ['disappointment'],
#  ['very', 'prompt'],
#  ['excellent', 'product'],
#  ['very', 'pleased'],
#  ['waste', 'money'],
#  ['i', 'especially', 'love', 'long', 'battery'],
#  ['stupid',
#   'keep',
#   'buying',
#   'new',
#   'car',
#   'headphones',
#   'car',
#   'kits',
#   'every',
#   'time',
#   'new',
#   'phone',
#   'comes'],
#  ['works'],
#  ['plantronics', 'bluetooth', 'excelent'],
#  ['i',
#   'came',
#   'verizon',
#   'cingulair',
#   'nicer',
#   'cell',
#   'first',
#   'thing',
#   'i',
#   'noticed',
#   'really',
#   'bad'],
#  ['looking', 'new'],
#  ['i', 'highly', 'recommend', 'device'],
#  ['jawbone', 'era', 'awesome'],
#  ['we',
#   'received',
#   'white',
#   'colored',
#   'battery',
#   'goes',
#   'dead',
#   'couple',
#   'hoursthe',
#   'original',
#   'used',
#   'last',
#   'week',
#   'still',
#   'lasts',
#   'longer',
#   'thereplacement'],
#  ['after', 'year', 'battery', 'went', 'completely', 'dead'],
#  ['i', 'used', 'several', 'phone', 'two', 'one'],
#  ['an', 'awesome', 'new', 'look', 'for', 'fall'],
#  ['this', 'first', 'phone', 'cheaply'],
#  ['att', 'not', 'sound', 'distorted', 'yell'],
#  ['the', 'plastic', 'breaks', 'really', 'easy'],
#  ['price', 'good'],
#  ['make', 'mistake', 'i'],
#  ['oh', 'i', 'forgot', 'also', 'mention', 'weird', 'color', 'effect'],
#  ['using', 'iriver', 'spinn', 'fits'],
#  ['also', 'area', 'unit', 'not', 'fond', 'magnetic'],
#  ['i', 'psyched', 'phone', 'appointments', 'contacts', 'gets', 'great'],
#  ['every', 'thing', 'phone', 'work', 'like'],
#  ['another',
#   'note',
#   'appearance',
#   'really',
#   'looks',
#   'rather',
#   'especially',
#   'black'],
#  ['really'],
#  ['my', 'sanyo', 'survived', 'dozens', 'drops', 'blacktop', 'without', 'ill'],
#  ['fantastic'],
#  ['it', 'finds', 'cell', 'phone', 'right', 'away', 'i', 'enter'],
#  ['low'],
#  ['i', 'highly', 'recommend', 'modest', 'priced', 'cellular'],
#  ['but', 'get', 'better', 'reception', 'clarity', 'phone'],
#  ['warning', 'stay'],
#  ['i', 'wish', 'i', 'could', 'return', 'unit', 'get', 'back'],
#  ['awsome', 'device', 'works'],
#  ['i', 'used', 'talk', 'hours', 'battery', 'would', 'literally', 'drained'],
#  ['if', 'find', 'unit', 'comes', 'one', 'earpad', 'would', 'not', 'recommend'],
#  ['very'],
#  ['i',
#   'might',
#   'gotten',
#   'i',
#   'would',
#   'not',
#   'risk',
#   'buying',
#   'built',
#   'quality'],
#  ['they', 'made', 'case', 'small', 'difficult'],
#  ['restored', 'phone', 'like', 'new'],
#  ['i',
#   'would',
#   'recommend',
#   'purchasing',
#   'jabra',
#   'series',
#   'works',
#   'flawlessly',
#   'moto',
#   'go'],
#  ['i', 'searched', 'found', 'one', 'best'],
#  ['does', 'not'],
#  ['very', 'happy'],
#  ['the',
#   'screen',
#   'size',
#   'key',
#   'pad',
#   'lit',
#   'well',
#   'camera',
#   'quality',
#   'excellent',
#   'camera'],
#  ['really', 'nothing', 'bad', 'i', 'say'],
#  ['glad', 'found', 'product', 'amazon', 'hard', 'high'],
#  ['portable'],
#  ['my', 'colleague', 'i', 'get', 'great', 'little', 'performance'],
#  ['i',
#   'even',
#   'fully',
#   'charged',
#   'i',
#   'went',
#   'bed',
#   'turned',
#   'blue',
#   'tooth',
#   'noticed',
#   'left'],
#  ['also',
#   'problems',
#   'phone',
#   'reading',
#   'memory',
#   'card',
#   'i',
#   'always',
#   'turn'],
#  ['not', 'good', 'wearing', 'hat'],
#  ['timely', 'shipment', 'quality'],
#  ['nice', 'solid'],
#  ['very', 'well', 'made', 'fits', 'surefire'],
#  ['horrible'],
#  ['battery'],
#  ['we', 'would', 'recommend'],
#  ['cant', 'get', 'software', 'work'],
#  [],
#  ['poor', 'voice'],
#  ['the', 'battery', 'works'],
#  ['no', 'buyers', 'remorse'],
#  ['very', 'disappointed'],
#  ['i',
#   'find',
#   'inexcusable',
#   'probably',
#   'returning',
#   'phone',
#   'perhaps',
#   'changing'],
#  ['looks', 'great'],
#  ['i', 'tmobile', 'service', 'years', 'i', 'pretty', 'happy'],
#  ['the', 'update', 'procedure', 'difficult'],
#  ['i', 'hate', 'anything', 'goes'],
#  ['great', 'software'],
#  ['the', 'delivery'],
#  ['very', 'easy'],
#  ['uncomfortable', 'in', 'use', 'lg'],
#  ['the', 'volume', 'switch', 'rocketed', 'unit', 'destination'],
#  ['it',
#   'holds',
#   'charge',
#   'long',
#   'reasonably',
#   'comfortable',
#   'conditions',
#   'quality',
#   'sound'],
#  ['like', 'return'],
#  ['the',
#   'keyboard',
#   'really',
#   'worthwhile',
#   'usefulness',
#   'sturdy',
#   'enough',
#   'i',
#   'expect'],
#  ['difficult', 'understand', 'even', 'though', 'pricing', 'plans'],
#  ['after', 'charging', 'batteries', 'work'],
#  ['you', 'regret'],
#  ['i', 'love'],
#  ['a'],
#  ['its', 'not', 'user'],
#  ['unfortunately',
#   'ability',
#   'actually',
#   'know',
#   'receiving',
#   'call',
#   'rather',
#   'important',
#   'feature',
#   'phone',
#   'pitiful'],
#  ['then', 'i', 'exchanged', 'even'],
#  ['this', 'results', 'phone', 'either', 'stuck', 'max', 'volume'],
#  ['this', 'pda'],
#  ['it', 'super', 'charged', 'use', 'small', 'hybrid', 'excels'],
#  ['i',
#   'would',
#   'definitely',
#   'recommend',
#   'jabra',
#   'looking',
#   'clarity',
#   'great'],
#  ['i', 'verizon', 'years', 'ago', 'really', 'liked'],
#  ['pretty', 'piece'],
#  ['plug', 'wrong'],
#  ['works'],
#  ['save', 'item', 'months'],
#  ['bad'],
#  ['well', 'im'],
#  ['the', 'bose', 'noise', 'cancelling', 'important', 'nyc'],
#  ['this', 'battery', 'excellent'],
#  ['defective'],
#  ['i', 'would', 'given', 'star', 'i'],
#  ['i', 'wear', 'glasses', 'fits', 'fine'],
#  ['the', 'sound', 'quality', 'device', 'really', 'quiet', 'almost', 'hear'],
#  ['i', 'would', 'not', 'recommend', 'item'],
#  ['the', 'holster', 'arrived', 'not', 'match', 'photo'],
#  ['problems'],
#  ['as', 'earlier', 'review', 'plug', 'charger', 'nothing'],
#  ['this', 'frog', 'phone', 'charm', 'adorable', 'eye'],
#  ['you',
#   'never',
#   'know',
#   'pushed',
#   'hard',
#   'enough',
#   'right',
#   'number',
#   'times',
#   'function',
#   'want'],
#  ['the', 'sound', 'clear', 'people', 'i', 'talk', 'amazed', 'quality'],
#  ['i',
#   'got',
#   'aluminum',
#   'case',
#   'new',
#   'palm',
#   'vx',
#   'worked',
#   'really',
#   'protected',
#   'handheld',
#   'perfectly'],
#  ['good', 'well'],
#  ['mobile', 'phone', 'tools', 'must'],
#  ['i', 'impressed', 'job', 'motorola', 'sturdiness'],
#  ['i',
#   'received',
#   'orders',
#   'well',
#   'within',
#   'shipping',
#   'everything',
#   'good',
#   'working',
#   'order',
#   'i',
#   'excited'],
#  ['the', 'phone', 'sturdy'],
#  ['i', 'not', 'impressed', 'would', 'not', 'recommend', 'item'],
#  ['my',
#   'complaint',
#   'standard',
#   'sound',
#   'volume',
#   'little',
#   'low',
#   'even',
#   'turned'],
#  ['thanks', 'amazon', 'things', 'i', 'need', 'good'],
#  ['i', 'ended', 'sliding', 'edge', 'pants', 'back', 'pockets'],
#  ['i', 'go', 'store', 'bought', 'new', 'nokia', 'phone', 'working'],
#  ['works'],
#  ['really'],
#  ['switch'],
#  ['the', 'noise', 'shield'],
#  ['no', 'real'],
#  ['razr', 'battery', 'good'],
#  ['keep', 'good', 'work'],
#  ['they', 'refuse', 'refund'],
#  ['unfortunately',
#   'easy',
#   'accidentally',
#   'activate',
#   'buttons',
#   'accidentally',
#   'touch',
#   'phone',
#   'face'],
#  ['so', 'i', 'basically', 'threw', 'money', 'window'],
#  ['great', 'case'],
#  ['all',
#   'took',
#   'one',
#   'drop',
#   'inches',
#   'kitchen',
#   'counter',
#   'not',
#   'impressed',
#   'i',
#   'not'],
#  ['bluetooth',
#   'range',
#   'good',
#   'days',
#   'ago',
#   'i',
#   'left',
#   'phone',
#   'got',
#   'carried',
#   'conversation',
#   'without'],
#  ['impressive', 'practical', 'setup', 'ample', 'storage'],
#  ['the',
#   'eargels',
#   'channel',
#   'sound',
#   'directly',
#   'ear',
#   'seem',
#   'increase',
#   'sound',
#   'volume'],
#  ['none', 'new', 'ones', 'ever', 'quite', 'worked'],
#  ['i', 'glad', 'i', 'purchased'],
#  ['missed', 'numerous', 'calls'],
#  ['perhaps', 'phone', 'people', 'cannot', 'hear', 'i', 'use'],
#  ['buy'],
#  ['stuff', 'not', 'work'],
#  ['no', 'not', 'even', 'happier', 'new', 'one'],
#  ['worst',
#   'software',
#   'ever',
#   'if',
#   'i',
#   'could',
#   'give',
#   'zero',
#   'stars',
#   'i'],
#  ['trying', 'make', 'call', 'exercise'],
#  ['the', 'case', 'flimsy', 'piece', 'plastic', 'front', 'side', 'protection'],
#  ['i', 'jabra', 'earset', 'happy', 'sound', 'especially'],
#  ['i', 'love', 'really', 'pretty', 'good'],
#  ['thank', 'great'],
#  ['its', 'total'],
#  ['the', 'seller', 'understanding', 'i', 'would', 'definitely', 'buy'],
#  ['i', 'give', 'wirefly', 'contact', 'inform'],
#  [],
#  ['great', 'product'],
#  ['i', 'purchased', 'family', 'enjoy', 'clarity', 'ease', 'use'],
#  ['virgin', 'wireless', 'rocks', 'cheap', 'little'],
#  ['none', 'buy'],
#  ['low',
#   'quality',
#   'casing',
#   'around',
#   'insert',
#   'poorly',
#   'super',
#   'glued',
#   'slid'],
#  ['please', 'dont', 'waste'],
#  ['all', 'quite', 'satisfied'],
#  ['if', 'looking', 'good', 'quality', 'motorola', 'headset', 'keep'],
#  ['yet', 'plantronincs', 'continues', 'use', 'flawed', 'charger'],
#  ['disapointing'],
#  ['cumbersome'],
#  ['great',
#   'new',
#   'packaged',
#   'nice',
#   'works',
#   'problems',
#   'came',
#   'less',
#   'time',
#   'i'],
#  ['great'],
#  ['a', 'piece', 'of'],
#  ['my',
#   'experience',
#   'this',
#   'fourth',
#   'bluetooth',
#   'much',
#   'comfortable',
#   'last',
#   'jabra',
#   'i'],
#  ['this', 'fixes'],
#  ['worst'],
#  ['i', 'happy'],
#  ['trouble', 'accessing', 'downloading', 'ringtones', 'performing'],
#  ['i', 'barely', 'ever', 'hear', 'constantly', 'saying'],
#  ['the', 'battery', 'life', 'highly'],
#  ['that', 'company'],
#  ['it', 'everything', 'description', 'said'],
#  ['due', 'happening', 'every', 'call', 'i', 'forced', 'stop', 'using'],
#  ['it',
#   'works',
#   'great',
#   'car',
#   'especially',
#   'cannot',
#   'plug',
#   'two',
#   'adapters'],
#  ['verizon',
#   'tech',
#   'support',
#   'walked',
#   'none',
#   'worked',
#   'i',
#   'ended',
#   'hard',
#   'wiping'],
#  ['voice', 'signal', 'dropped'],
#  ['it',
#   'plays',
#   'louder',
#   'speaker',
#   'price',
#   'low',
#   'would',
#   'think',
#   'quality'],
#  ['better'],
#  ['it',
#   'feels',
#   'poorly',
#   'menus',
#   'difficult',
#   'buttons',
#   'recessed',
#   'difficult',
#   'push'],
#  ['battery', 'holding'],
#  ['also', 'difficult', 'put', 'recommend', 'avoiding'],
#  ['i', 'used', 'two', 'always', 'easy', 'hear'],
#  ['i',
#   'got',
#   'car',
#   'charger',
#   'not',
#   'even',
#   'week',
#   'charger',
#   'went',
#   'plug',
#   'started'],
#  ['sprint', 'terrible', 'customer'],
#  ['linked', 'phone', 'without'],
#  ['they'],
#  ['easy'],
#  ['better', 'than'],
#  ['what', 'possesed', 'get', 'i'],
#  ['piece'],
#  ['a', 'pretty', 'good'],
#  ['this', 'great'],
#  ['for', 'price', 'excellent', 'i', 'would', 'highly'],
#  ['their', 'research', 'development', 'division', 'obviously', 'knows'],
#  ['the', 'real', 'killer', 'course'],
#  ['those', 'phones', 'working', 'fine'],
#  ['i', 'happy'],
#  ['poor'],
#  ['this'],
#  ['i', 'would', 'recommend', 'phone', 'new'],
#  ['sprint', 'charges'],
#  ['it', 'feel', 'look'],
#  ['it', 'fits', 'ear', 'well', 'comfortable'],
#  ['it', 'work', 'europe'],
#  ['clipping', 'belt', 'deffinitely', 'make', 'feel', 'like'],
#  ['i',
#   'like',
#   'design',
#   'look',
#   'jabra',
#   'behing',
#   'ear',
#   'headsets',
#   'pretty',
#   'comfortible',
#   'wear',
#   'hours',
#   'day',
#   'without',
#   'pain'],
#  ['i',
#   'amazed',
#   'quick',
#   'arrival',
#   'two',
#   'original',
#   'lg',
#   'cell',
#   'phone',
#   'batteries',
#   'fraction'],
#  ['worst', 'phone', 'crappy', 'samsung', 'worst', 'ever'],
#  ['charger', 'worked', 'week', 'completely', 'stopped', 'charging'],
#  ['poor'],
#  ['however', 'i', 'needed', 'better'],
#  ['you',
#   'need',
#   'two',
#   'hands',
#   'operate',
#   'software',
#   'interface',
#   'decade',
#   'old',
#   'cannot',
#   'compete',
#   'new',
#   'software'],
#  ['worked',
#   'well',
#   'paired',
#   'treo',
#   'skype',
#   'headset',
#   'pc',
#   'usb',
#   'bluetooth'],
#  ['steer',
#   'clear',
#   'product',
#   'go',
#   'genuine',
#   'palm',
#   'replacementr',
#   'come'],
#  ['do', 'not', 'buy', 'do', 'not', 'buyit', 'sucks'],
#  ['this', 'great', 'sure', 'beats', 'using'],
#  ['i', 'seriously', 'not', 'believe', 'worth', 'steep', 'price'],
#  ['all',
#   'cases',
#   'tried',
#   'normally',
#   'fall',
#   'apart',
#   'months',
#   'one',
#   'seems',
#   'long'],
#  ['very', 'dissapointing'],
#  ['make', 'mistake', 'i', 'please', 'buy'],
#  ['this', 'phone', 'might', 'well', 'worst', 'ever'],
#  ['case',
#   'less',
#   'extra',
#   'i',
#   'originally',
#   'put',
#   'later',
#   'discarded',
#   'scratched'],
#  ['i', 'recommend', 'igo', 'anyone', 'different', 'brand', 'cell', 'players'],
#  ['bother', 'go'],
#  ['i',
#   'posted',
#   'detailed',
#   'comments',
#   'grey',
#   'black',
#   'fire',
#   'red',
#   'great'],
#  ['i', 'not', 'problem', 'item', 'would', 'order'],
#  ['you', 'get', 'pay', 'i'],
#  ['not',
#   'software',
#   'great',
#   'job',
#   'i',
#   'could',
#   'also',
#   'make',
#   'ringtones',
#   'form',
#   'existing',
#   'cds',
#   'without',
#   'internet'],
#  ['im',
#   'surprised',
#   'good',
#   'quality',
#   'car',
#   'charger',
#   'not',
#   'much',
#   'reviews'],
#  ['these'],
#  ['bt',
#   'headsets',
#   'currently',
#   'not',
#   'good',
#   'real',
#   'time',
#   'games',
#   'like',
#   'shooters',
#   'since',
#   'audio',
#   'delay',
#   'messes'],
#  ['i',
#   'used',
#   'bitpim',
#   'free',
#   'program',
#   'find',
#   'transfer',
#   'data',
#   'price',
#   'cable'],
#  ['disappointing', 'accessory', 'good'],
#  ['performed', 'awful', 'tinny', 'incoming', 'sound', 'severe', 'echo', 'end'],
#  ['very'],
#  ['obviously', 'terrible', 'customer', 'get', 'pay'],
#  ['they',
#   'not',
#   'last',
#   'not',
#   'overly',
#   'expensive',
#   'operate',
#   'sound',
#   'much',
#   'better',
#   'others',
#   'i'],
#  ['i',
#   'contacted',
#   'company',
#   'told',
#   'although',
#   'unit',
#   'still',
#   'i',
#   'produce',
#   'receipt',
#   'i'],
#  ['linksys', 'way', 'exchange', 'bad', 'phone', 'refurb', 'unit'],
#  ['phone', 'sturdy', 'nokia', 'bar', 'phones'],
#  ['great'],
#  ['when', 'i', 'placed', 'treo', 'not', 'not', 'a', 'lot', 'extra', 'room'],
#  [],
#  ['battery'],
#  ['i', 'found', 'product', 'easy', 'set'],
#  ['the', 'earpiece', 'large', 'keeps', 'falling'],
#  ['utter', 'sound', 'quality'],
#  ['the', 'charger', 'arrived', 'within', 'promised', 'not'],
#  ['no', 'ear', 'loop', 'tiny', 'sound'],
#  ['three',
#   'four',
#   'times',
#   'spring',
#   'latch',
#   'broke',
#   'i',
#   'could',
#   'not',
#   'use',
#   'longer'],
#  ['the',
#   'handsfree',
#   'part',
#   'works',
#   'car',
#   'tries',
#   'download',
#   'address',
#   'treo',
#   'i',
#   'still',
#   'rate',
#   'device'],
#  ['talk', 'useless', 'customer'],
#  ['it', 'felt', 'light'],
#  ['this',
#   'not',
#   'fit',
#   'palm',
#   'tungsten',
#   'broke',
#   'first',
#   'time',
#   'i',
#   'tried',
#   'plug'],
#  ['happy', 'good', 'quality', 'low'],
#  ['i', 'love', 'look', 'feel', 'samsung'],
#  ['its', 'sharp', 'blue', 'nice'],
#  ['does', 'everything'],
#  ['i', 'could', 'not', 'recommend'],
#  ['nice'],
#  ['looks', 'good', 'case', 'huge'],
#  ['much', 'less', 'jawbone', 'i', 'going', 'replace'],
#  ['setup', 'went'],
#  ['extremely', 'slow', 'takes', 'forever', 'anything'],
#  ['a', 'must', 'study', 'anyone', 'interested', 'industrial'],
#  ['the', 'first', 'thing', 'happened', 'tracking'],
#  ['it', 'well', 'easy', 'access', 'phone', 'detachable', 'belt'],
#  ['then',
#   'i',
#   'continue',
#   'pairing',
#   'periodically',
#   'since',
#   'somehow',
#   'kept'],
#  ['upload', 'ringtones', 'third'],
#  ['bluetooth',
#   'not',
#   'phone',
#   'locks',
#   'screens',
#   'flash',
#   'makes',
#   'calls',
#   'randomly',
#   'pocket'],
#  ['truly'],
#  ['it', 'works', 'fine', 'motorola', 'lot', 'better', 'battery'],
#  ['the', 'volume', 'ringer', 'real', 'good', 'choices'],
#  ['and', 'none', 'tones'],
#  ['camera', 'color', 'balance'],
#  ['this',
#   'product',
#   'clearly',
#   'not',
#   'ready',
#   'prime',
#   'i',
#   'care',
#   'cool',
#   'tell',
#   'call',
#   'coming'],
#  ['i', 'love', 'ringtones'],
#  ['chinese', 'forgeries'],
#  ['easy', 'pair', 'samsung'],
#  ['the', 'instructions', 'explain', 'microphone', 'jack', 'could'],
#  ['would', 'advise', 'not', 'purchase', 'item', 'never', 'worked'],
#  ['too', 'bad', 'pay', 'month'],
#  ['works'],
#  ['the', 'nokia', 'usb', 'cable', 'not', 'work'],
#  ['clear', 'crisp'],
#  ['i', 'use', 'smallest', 'earpieces', 'stays', 'pretty'],
#  ['the', 'biggest', 'complaint', 'i', 'battery', 'drains'],
#  ['the',
#   'design',
#   'might',
#   'ergonomic',
#   'theory',
#   'i',
#   'could',
#   'not',
#   'stand'],
#  ['do', 'not', 'buy', 'want', 'use'],
#  ['the', 'phone', 'also', 'take', 'great', 'pictures', 'even', 'video'],
#  ['it', 'make', 'look'],
#  ['because', 'ears', 'background', 'not', 'distracting'],
#  ['comfortable',
#   'fit',
#   'need',
#   'headset',
#   'comfortable',
#   'least',
#   'hour',
#   'not',
#   'entire'],
#  ['phone',
#   'seem',
#   'accept',
#   'anything',
#   'except',
#   'cbr',
#   'preferably',
#   'ripped',
#   'windows',
#   'media'],
#  ['you', 'beat', 'price'],
#  ['comes',
#   'strong',
#   'light',
#   'use',
#   'light',
#   'camera',
#   'even',
#   'flash',
#   'sos',
#   'signals'],
#  ['lightweight', 'works'],
#  ['so'],
#  ['i', 'love', 'cable', 'allows', 'connect', 'device'],
#  ['so', 'anyone', 'near', 'hear', 'part'],
#  ['this', 'cool', 'cases', 'open', 'allowing', 'screen', 'get', 'scratched'],
#  ['i', 'bought', 'phone', 'replacement', 'startac', 'regretted'],
#  ['appears', 'actually', 'outperform', 'original', 'battery', 'china', 'came'],
#  ['store', 'anything', 'phone', 'numbers'],
#  ['it', 'lasts', 'less', 'i', 'actually', 'try', 'use', 'wife', 'phone'],
#  ['poor'],
#  ['jabra', 'ear', 'gels'],
#  ['not', 'worth'],
#  ['the', 'phone', 'crashed', 'completely', 'i', 'get'],
#  ['it',
#   'quit',
#   'working',
#   'used',
#   'i',
#   'purchased',
#   'another',
#   'one',
#   'best',
#   'headset',
#   'ever'],
#  ['unfortunately',
#   'not',
#   'recharge',
#   'iphone',
#   'despite',
#   'connecting',
#   'multiple',
#   'power',
#   'sources',
#   'external',
#   'wall'],
#  ['it', 'great'],
#  ['simply',
#   'want',
#   'small',
#   'flip',
#   'phone',
#   'look',
#   'elsewhere',
#   'extra',
#   'bells',
#   'whistles'],
#  ['good', 'works', 'fine', 'power', 'via', 'wall'],
#  ['my',
#   'phone',
#   'slide',
#   'around',
#   'car',
#   'grip',
#   'prevents',
#   'phone',
#   'slipping'],
#  ['this', 'simply', 'best', 'bluetooth', 'headset', 'sound'],
#  ['think', 'plan', 'sure', 'last', 'moto', 'phone'],
#  ['in', 'span', 'i', 'two', 'people', 'exclaim', 'new', 'phone'],
#  ['i', 'always', 'used', 'corded', 'headsets', 'freedom', 'wireless'],
#  ['this', 'case', 'passed', 'one', 'year', 'mark', 'shows', 'signs'],
#  ['other', 'leather', 'nice', 'fit', 'cut', 'face', 'good'],
#  ['it', 'everything', 'i', 'need', 'i', 'ask'],
#  ['after', 'receiving', 'using', 'product', 'days'],
#  ['this',
#   'product',
#   'makes',
#   'working',
#   'lot',
#   'easier',
#   'i',
#   'go',
#   'copier',
#   'waiting',
#   'hold'],
#  ['none', 'three', 'sizes', 'sent', 'headset', 'would', 'stay'],
#  ['best', 'customer', 'service'],
#  ['arrived', 'quickly', 'much', 'less', 'expensive', 'others'],
#  ['we', 'tried', 'units', 'failed', 'within', 'pros'],
#  ['provides', 'good', 'protection', 'looks'],
#  ['krussel', 'always'],
#  ['the', 'tracfonewebsite', 'user', 'friendly', 'makes', 'easy'],
#  ['the', 'design'],
#  ['i', 'great', 'reception'],
#  ['i', 'would', 'highly', 'recommend'],
#  ['use', 'unit', 'not', 'good'],
#  ['it', 'dit', 'not', 'work', 'time', 'nokia'],
#  ['bought', 'mainly', 'broke', 'soon'],
#  ['if', 'like', 'loud', 'buzzing', 'override', 'phone'],
#  ['fantastic', 'buy', 'get', 'whatever', 'next', 'phone'],
#  ['stay', 'away'],
#  ['this', 'blueant', 'supertooth', 'phone', 'speaker'],
#  ['does', 'not'],
#  ['item',
#   'arrived',
#   'quickly',
#   'works',
#   'great',
#   'metro',
#   'pcs',
#   'samsung',
#   'slider',
#   'phone',
#   'sony',
#   'premium',
#   'sound',
#   'ear'],
#  ['it',
#   'plenty',
#   'battery',
#   'confortable',
#   'wear',
#   'somewhat',
#   'extended',
#   'periods'],
#  [],
#  ['blue', 'ant', 'easy'],
#  ['cheap', 'hey', 'was', 'pleasantly', 'suprised', 'given', 'low', 'cost'],
#  ['the',
#   'camera',
#   'phone',
#   'may',
#   'used',
#   'dustpan',
#   'rather',
#   'using',
#   'disposable'],
#  ['then', 'days', 'later', 'puff', 'smoke', 'came', 'phone'],
#  ['convenient',
#   'simple',
#   'use',
#   'gets',
#   'job',
#   'done',
#   'makes',
#   'car',
#   'ride',
#   'much'],
#  ['the', 'nano', 'stated', 'son'],
#  ['the', 'sound', 'quality', 'excellent'],
#  ['its', 'best', 'headset', 'i'],
#  ['would', 'not'],
#  ['they',
#   'around',
#   'years',
#   'carries',
#   'highest',
#   'quality',
#   'screen',
#   'protector',
#   'i',
#   'found'],
#  ['just', 'i'],
#  ['this', 'particular', 'model', 'would', 'not', 'work', 'motorola', 'q'],
#  ['wont', 'work', 'right', 'atleast'],
#  ['addition', 'feels', 'looks', 'phone', 'lightweight', 'cheap'],
#  ['but',
#   'problems',
#   'put',
#   'money',
#   'somewhere',
#   'cingular',
#   'not',
#   'support'],
#  ['i', 'really', 'wanted', 'plantronics', 'right', 'many', 'issues', 'good'],
#  ['great'],
#  ['crisp'],
#  ['after', 'first', 'charge', 'kept', 'going', 'dead'],
#  ['very', 'cheap', 'creaks', 'like', 'old', 'wooden'],
#  ['i', 'get', 'absolutely', 'horrible', 'reception', 'phones', 'i', 'not'],
#  ['the', 'reception', 'generally'],
#  ['excellent', 'battery', 'life', 'inconspicuous'],
#  ['great'],
#  ['i', 'highly', 'recommend'],
#  [],
#  ['this', 'great'],
#  ['after',
#   'phone',
#   'got',
#   'year',
#   'slowly',
#   'breaking',
#   'despite',
#   'much',
#   'care'],
#  ['i', 'sorry', 'i', 'made'],
#  ['i',
#   'bought',
#   'hoping',
#   'i',
#   'could',
#   'make',
#   'bluetooth',
#   'headset',
#   'fit',
#   'better',
#   'things',
#   'made',
#   'impossible'],
#  ['treo',
#   'refused',
#   'replace',
#   'forced',
#   'buy',
#   'another',
#   'phone',
#   'without',
#   'kind',
#   'upgrade'],
#  ['it'],
#  ['i', 'think', 'would', 'hold', 'securly'],
#  ['this', 'allows', 'possibility', 'double', 'booking', 'date', 'time'],
#  ['they', 'work', 'weeks'],
#  ['it', 'simple', 'use', 'i', 'like'],
#  ['great',
#   'tool',
#   'data',
#   'sure',
#   'use',
#   'activesync',
#   'optimal',
#   'data',
#   'synchronization'],
#  ['i', 'use', 'case', 'smell'],
#  ['not', 'what', 'i'],
#  ['i', 'cases', 'would', 'order'],
#  ['great'],
#  ['i', 'bought', 'battery', 'coupon', 'amazon', 'happy'],
#  ['the', 'internet', 'access', 'rare', 'instance'],
#  ['perfect'],
#  ['five', 'star'],
#  ['a',
#   'good',
#   'quality',
#   'i',
#   'bought',
#   'i',
#   'bought',
#   'cheapy',
#   'big',
#   'lots',
#   'sounded',
#   'awful',
#   'people',
#   'end',
#   'hear'],
#  ['down'],
#  ['i',
#   'tried',
#   'talking',
#   'real',
#   'loud',
#   'shouting',
#   'telephone',
#   'gets',
#   'old',
#   'i',
#   'still',
#   'told'],
#  ['good', 'works'],
#  ['for', 'price', 'great'],
#  ['great'],
#  ['if', 'completely'],
#  ['yes', 'shiny', 'front', 'side', 'i', 'love'],
#  ['does', 'not'],
#  ['at',
#   'first',
#   'i',
#   'thought',
#   'i',
#   'grtting',
#   'good',
#   'deal',
#   'i',
#   'plugged',
#   'phone'],
#  ['the', 'reception', 'headset'],
#  ['thumbs', 'seller'],
#  ['i',
#   'verizon',
#   'lg',
#   'phone',
#   'work',
#   'well',
#   'good',
#   'reception',
#   'range',
#   'exceeds',
#   'feet',
#   'line'],
#  ['improper', 'i', 'return'],
#  ['it', 'works', 'it'],
#  ['battery', 'quite'],
#  ['the', 'jabra', 'eargels', 'fit', 'ears'],
#  ['battery'],
#  ['i', 'checked', 'everywhere', 'feature', 'really'],
#  ['product', 'exactly'],
#  ['gets', 'signal', 'verizon', 'phones'],
#  [],
#  ['i', 'would', 'recommend'],
#  ['plan', 'ordering'],
#  ['that', 'camera', 'many', 'cool', 'effects', 'play', 'video', 'decent'],
#  ['i', 'satisfied', 'cell', 'phone', 'day'],
#  ['they',
#   'keep',
#   'getting',
#   'better',
#   'better',
#   'third',
#   'one',
#   'numerous',
#   'palms'],
#  ['awkward', 'use'],
#  ['the', 'shipping', 'time', 'also'],
#  ['not', 'good', 'i'],
#  ['good'],
#  [],
#  ['really', 'good'],
#  ['unfortunately', 'not'],
#  ['all', 'three', 'broke', 'within', 'two', 'months'],
#  ['dont', 'buy'],
#  ['my', 'father', 'battery'],
#  ['ear', 'pads', 'come', 'easily', 'one', 'week', 'i', 'lost'],
#  ['the',
#   'calls',
#   'phone',
#   'comes',
#   'screen',
#   'goes',
#   'black',
#   'worst',
#   'stops',
#   'ringing'],
#  ['horrible'],
#  ['i', 'like', 'nokia'],
#  ['reaching', 'bottom', 'row', 'send', 'end', 'keys', 'not', 'i', 'expect'],
#  ['i', 'bought', 'nokia', 'cell', 'phone', 'weeks', 'ago'],
#  ['it',
#   'would',
#   'take',
#   'long',
#   'describe',
#   'bad',
#   'customer',
#   'service',
#   'experience'],
#  ['very', 'disappointing', 'thing', 'no'],
#  ['my', 'car', 'not', 'accept'],
#  ['product',
#   'since',
#   'not',
#   'enough',
#   'charging',
#   'current',
#   'charge',
#   'cellphones',
#   'i',
#   'planning',
#   'use'],
#  ['not', 'says'],
#  ['stay', 'away', 'from'],
#  ['used'],
#  ['very', 'unreliable', 'service'],
#  ['not', 'good', 'enough'],
#  ['i', 'bought', 'two', 'neither'],
#  ['it', 'looks'],
#  ['this', 'excellent', 'especially', 'paired'],
#  ['i', 'read', 'reviews', 'i', 'problem'],
#  ['these', 'products', 'cover', 'important', 'light', 'sensor', 'ear'],
#  ['comfortable'],
#  ['just', 'not'],
#  ['poor'],
#  [],
#  ['if', 'i', 'take', 'battery', 'drops', 'starts', 'letting', 'know'],
#  ['terrible', 'waste'],
#  ['last', 'time', 'buying'],
#  ['it', 'waste'],
#  ['so', 'far', 'worked', 'like'],
#  ['i'],
#  ['best',
#   'part',
#   'download',
#   'pictures',
#   'laptop',
#   'using',
#   'even',
#   'send',
#   'pictures',
#   'laptop'],
#  ['would', 'recommend'],
#  ['choice', 'headset', 'good', 'good', 'noise'],
#  ['nice', 'feels', 'good'],
#  ['the', 'item', 'received'],
#  ['just', 'really', 'so', 'probably', 'best', 'bt', 'headset', 'i', 'ever'],
#  ['works'],
#  ['i', 'received', 'headset', 'good', 'time', 'happy'],
#  ['i',
#   'pleased',
#   'see',
#   'i',
#   'could',
#   'replace',
#   'well',
#   'travled',
#   'swivel',
#   'holster',
#   'blackberry'],
#  ['my', 'sister', 'one', 'also', 'loves'],
#  ['good'],
#  ['this', 'far', 'worst', 'purchase', 'made'],
#  ['excellent'],
#  [],
#  ['does', 'not', 'work', 'listening', 'music', 'cingular'],
#  ['it', 'seems', 'completely', 'holding', 'keeping', 'iphone'],
#  ['the', 'bottowm', 'cheap', 'gimmick'],
#  ['having', 'trouble'],
#  ['the', 'good', 'thing', 'fits', 'comfortably', 'small'],
#  ['warning', 'do', 'not'],
#  ['i', 'pairing', 'i', 'could', 'not', 'happier'],
#  ['when', 'battery', 'connection', 'broken', 'device', 'turned'],
#  ['i', 'want', 'clip', 'going', 'top', 'causing'],
#  ['best', 'headset'],
#  ['trust', 'website', 'expect', 'helpful'],
#  ['it',
#   'say',
#   'plantronics',
#   'maintains',
#   'flawless',
#   'connection',
#   'cell',
#   'static',
#   'normal'],
#  ['the', 'speaker', 'low', 'quality', 'making', 'ring', 'tones', 'sound'],
#  ['fits', 'came', 'three', 'sizes', 'earbud'],
#  ['excellent', 'product'],
#  ['bad'],
#  ['this', 'product', 'high', 'quality', 'chinese'],
#  ['it', 'quite', 'comfortable'],
#  ['great'],
#  ['buy', 'product', 'it'],
#  ['everything', 'product'],
#  ['the',
#   'pairing',
#   'two',
#   'devices',
#   'easy',
#   'barely',
#   'took',
#   'couple',
#   'minutes',
#   'i',
#   'started',
#   'making',
#   'calls',
#   'voice',
#   'dialing'],
#  ['this', 'utterly', 'confusing', 'caused', 'lose', 'couple', 'important'],
#  ['terrible', 'phone'],
#  ['the', 'cutouts', 'buttons', 'placed'],
#  ['i', 'love', 'able', 'use', 'one', 'headset'],
#  ['problem', 'ear', 'loops', 'made', 'weak', 'material', 'break'],
#  ['not', 'nearly', 'good', 'looking', 'amazon', 'picture', 'makes'],
#  ['but',
#   'despite',
#   'case',
#   'exceptional',
#   'quality',
#   'well',
#   'worth',
#   'additional',
#   'costs',
#   'owning',
#   'official',
#   'oem'],
#  ['how', 'stupid'],
#  ['i', 'hear', 'driving', 'usually', 'even', 'put', 'loudest'],
#  ['seller', 'shipped', 'quickly', 'much', 'cheaper'],
#  ['good'],
#  ['so', 'i', 'bought', 'saved', 'alot'],
#  ['it',
#   'always',
#   'cuts',
#   'makes',
#   'beep',
#   'beep',
#   'beep',
#   'sound',
#   'says',
#   'signal'],
#  ['figure'],
#  ['my',
#   'phone',
#   'sounded',
#   'ok',
#   'not',
#   'great',
#   'phone',
#   'almost',
#   'totally',
#   'understand',
#   'word',
#   'said'],
#  ['so', 'i', 'take', 'battery', 'phone', 'put', 'back', 'together', 'restart'],
#  ['while',
#   'i',
#   'managed',
#   'bend',
#   'leaf',
#   'spring',
#   'back',
#   'metal',
#   'enough',
#   'stress',
#   'break',
#   'next'],
#  ['leopard', 'print', 'wonderfully'],
#  ['works'],
#  ['floppy', 'piece'],
#  ['much', 'better', 'hard', 'plastic'],
#  ['it', 'also', 'new'],
#  ['happy'],
#  ['cool'],
#  ['works'],
#  ['motorola', 'finally', 'got', 'voice', 'quality', 'bluetooth', 'headset'],
#  ['it', 'looses', 'connection', 'phone', 'even', 'within', 'couple', 'feet'],
#  ['would', 'really', 'recommend'],
#  ['makes', 'easier', 'keep', 'bluetooth', 'not', 'wearing'],
#  ['as', 'i', 'said'],
#  ['never', 'got'],
#  ['this', 'pair', 'headphones', 'worst', 'i', 'ever'],
#  ['drain', 'weak'],
#  ['does', 'not', 'charge', 'cingular'],
#  ['you', 'get', 'extra', 'minutes', 'carry', 'call', 'not', 'get', 'cut'],
#  ['fliptop',
#   'started',
#   'get',
#   'loose',
#   'wobbly',
#   'eventually',
#   'screen',
#   'went',
#   'black',
#   'i',
#   'receive',
#   'place'],
#  ['i', 'kept', 'catching', 'cable', 'seat', 'i', 'pull', 'phone', 'turn'],
#  ['the', 'headset', 'fulfills', 'requirements', 'i', 'happy'],
#  ['logitech', 'bluetooth', 'headset'],
#  ['i', 'like', 'fact', 'rests', 'lightly', 'rather'],
#  ['a', 'lot', 'websites', 'rating', 'good', 'phone'],
#  ['i', 'tried', 'cables', 'computer', 'ipod', 'works'],
#  ['the', 'mic', 'volume', 'quite'],
#  ['returning'],
#  ['i', 'not', 'maintain', 'connection', 'computer'],
#  ['it', 'easy', 'turn', 'car', 'volume', 'controls', 'quite'],
#  ['i', 'mine', 'year', 'christmas', 'i', 'bought', 'rest'],
#  ['easy', 'install', 'clear'],
#  ['nice'],
#  ['i', 'purchase', 'different'],
#  ['it', 'joy'],
#  ['very', 'much', 'disappointed'],
#  ['very', 'satisifed'],
#  ['it', 'charge'],
#  ['this', 'phone', 'get', 'i', 'bought', 'i', 'say'],
#  ['buttons'],
#  ['just', 'reading', 'specs', 'alone', 'makes', 'say'],
#  ['love', 'great'],
#  ['i',
#   'really',
#   'like',
#   'product',
#   'motorola',
#   'allot',
#   'clearer',
#   'ear',
#   'piece'],
#  ['keypads', 'tinny', 'i', 'sometimes', 'reach', 'wrong'],
#  ['i', 'exchanged', 'sony', 'ericson', 'pretty', 'happy'],
#  ['i', 'impressed', 'price'],
#  ['also', 'makes', 'easier', 'hold'],
#  ['i',
#   'use',
#   'product',
#   'motor',
#   'control',
#   'center',
#   'lot',
#   'high',
#   'voltage',
#   'humming',
#   'works'],
#  ['pretty'],
#  ['i', 'cannot', 'make', 'calls', 'certain'],
#  ['girl', 'complain', 'time', 'phone', 'wake', 'like', 'normal', 'phone'],
#  ['beautiful', 'styling'],
#  ['this',
#   'company',
#   'charge',
#   'restocking',
#   'fee',
#   'still',
#   'not',
#   'given',
#   'refund'],
#  ['trying', 'return'],
#  ['i', 'plugged', 'find', 'not', 'darn', 'thing'],
#  ['excellent'],
#  ['earbud', 'piece', 'breaks'],
#  ['lousy'],
#  ['this', 'phone', 'tries', 'hard', 'everything', 'fails', 'ability'],
#  ['it', 'best', 'charger', 'i', 'seen', 'market'],
#  ['sweetest'],
#  ['charger', 'seems', 'work'],
#  ['it',
#   'fits',
#   'securely',
#   'ear',
#   'hook',
#   'not',
#   'even',
#   'need',
#   'used',
#   'sound',
#   'better',
#   'directed',
#   'ear'],
#  ['not', 'enough'],
#  ['echo', 'unsatisfactory'],
#  ['could', 'take', 'videos', 'time', 'quality'],
#  ['waste'],
#  ['i', 'going', 'first', 'negatively', 'review'],
#  ['adapter', 'not', 'provide', 'enough', 'charging'],
#  ['there', 'much', 'hype', 'phone', 'i', 'assumed'],
#  ['you', 'also', 'cannot', 'take', 'pictures', 'case', 'lense'],
#  ['phone', 'falls'],
#  ['it', 'people', 'not', 'hear', 'i'],
#  ['the', 'text', 'messaging', 'feature', 'really', 'tricky'],
#  ['really', 'disappointed', 'i', 'charger'],
#  ['painful'],
#  ['lasted', 'one', 'day', 'blew'],
#  [],
#  ['kind', 'flops'],
#  ['the', 'screen', 'get', 'smudged', 'easily', 'touches', 'ear'],
#  ['what', 'piece', 'i', 'lose', 'calls'],
#  ['item', 'does', 'not', 'match'],
#  ['the', 'thing', 'disappoint', 'infra', 'red', 'port'],
#  ['you', 'not', 'answer', 'calls', 'never', 'worked'],
#  ...]

# %%
sw = stopwords.words('english')

# %%
cvect = CountVectorizer()
